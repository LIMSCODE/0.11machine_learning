# %% [markdown]
# # 6. 초기 탈모 예측

# %% [markdown]
# •지도 학습 분류 알고리즘 중 k-NN에 대해 이해한다
#
# •다항 분류 딥러닝 모델을 제작한다.
#
# •오차역전파법을 이해하고 딥러닝 가중치 갱신 과정을 파악한다.

# %% [markdown]
# ##일상생활과 연관된 몇 가지 속성으로 탈모 정도를 분류하는 인공지능을 만들어 보자

# %% [markdown]
# - 2017년부터 2021년까지 5년 간 원형 탈모증 등 병적 탈모로 병,의원에서 진료를 받은 국민이 115만 명에 달하는 것으로 나타났다.
# - 병적 탈모는 유전이나 노화로 인한 정상 탈모와 달리, 건강 악화나 약 부작용 등으로 인한 탈모를 말한다. 특히 화병, 우울증 같이 스트레스에서 비롯된 경우가 가장 많다
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [개념] k-NN이란?

# %% [markdown]
# k-NN: 분류하고자 하는 데이터와 가장 가까운 k개의 데이터를 찾아 다수의 클래스쪽으로 분류하는 알고리즘.
#
# k의 값에 따라 데이터 분류가 달라지기에 상황에 맞는 k값 설정이 필요.
#
# 다양한 분야에 활용 가능하고 구현이 비교적 간단하여 머신러닝 초보자에게 인기 있는 알고리즘
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # [실습]

# %% [markdown]
# # 데이터 불러오기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - 구글 다운로드 링크 혹은 삼양미디어 자료실에서 데이터를 다운 받을 수 있다.
# - 탈모 데이터를 읽고 상위 5개 데이터를 확인한다.

# %%
url = 'https://drive.google.com/uc?export=download&id=1YZH5iPMvC__xzyw4CGDBknOkaZhWAJDJ'
#dandruff 속성의 'None'값을 NaN(결측치)로 변환하는 것을 막기 위해 na_filter를 쓴다.
df = pd.read_excel(url, na_filter=False)
df.head( )
# Out:
#   hair_loss  stay_up_late pressure_level  coffee_consumed  \
# 0       Few             2            Low                0
# 1       Few             0            Low                0
# 2    Medium             3            Low                1
# 3       Few             2            Low                0
# 4       Few             2            Low                0
#
#    brain_working_duration stress_level swimming hair_washing dandruff
# 0                       1          Low       No            Y     None
# 1                       3          Low       No            N     None
# 2                       0          Low      Yes            Y     None
# 3                       1          Low       No            N     None
# 4                       1          Low       No            Y     None

# %% [markdown]
# **400명의 탈모 관련 정보**
#
# 머리숱, 두피압, 커피 섭취량, 스트레스 정도, 수영 여부 등등 정보가 있음.
#
# **value_count()** : 속성별 개수 출력
# - 머리숱 정도 : Few, Medium, Many, A lot
# - 두피압, 스트레스 : Low, Medium, High, Very High
# -일일 수영 여부, 머리 감기 여부 : Y, N
# - 비듬 정도 : None, Few, Many

# %%
print(df["hair_loss"].value_counts( ))
print(df["pressure_level"].value_counts( ))
print(df["stress_level"].value_counts( ))
print(df["swimming"].value_counts( ))
print(df["hair_washing"].value_counts( ))
print(df["dandruff"].value_counts( ))
# Out:
# hair_loss
# Few       169
# Medium    167
# Many       42
# A lot      22
# Name: count, dtype: int64
# pressure_level
# Low          275
# Medium        57
# High          45
# Very High     23
# Name: count, dtype: int64
# stress_level
# Low          261
# Medium        56
# High          45
# Very High     38
# Name: count, dtype: int64
# swimming
# No     307
# Yes     93
# Name: count, dtype: int64
# hair_washing
# N    209
# Y    191
# Name: count, dtype: int64
# dandruff
# None    289
# Few      76
# Many     35
# Name: count, dtype: int64

# %% [markdown]
# 모두 값이 있고 결측치 처리가 필요 없음을 알 수 있음.

# %%
df.isnull( ).sum( )
# Out:
# hair_loss                 0
# stay_up_late              0
# pressure_level            0
# coffee_consumed           0
# brain_working_duration    0
# stress_level              0
# swimming                  0
# hair_washing              0
# dandruff                  0
# dtype: int64

# %% [markdown]
# - 문자로 이루어진 데이터를 숫자로 라벨링한다.
# - replace() 함수로 각 문자를 0, 1, 2의 숫자로 대체한다.
# - 비듬 정도, 머리숱, 수영 여부, 머리 감기 여부 : 숫자 라벨링
# - 남은 두피압과 스트레스 정도는 한 번에 라벨링

# %%
df['dandruff'].replace('None',0,inplace = True)
df['dandruff'].replace('Few',1,inplace = True)
df['dandruff'].replace('Many',2, inplace = True)
df['hair_loss'].replace("Few", 0, inplace = True)
df['hair_loss'].replace("Medium", 1, inplace = True)
df['hair_loss'].replace("Many", 2, inplace = True)
df['hair_loss'].replace("A lot", 3, inplace = True)
df['swimming'].replace('Yes', 1, inplace = True)
df['swimming'].replace('No', 0, inplace = True)
df['hair_washing'].replace('Y', 1, inplace = True)
df['hair_washing'].replace('N', 0, inplace = True)
df.replace('Low', 0, inplace = True)
df.replace('Medium', 1, inplace = True)
df.replace('High', 2, inplace = True)
df.replace('Very High', 3, inplace = True)
df.head( )
# Out:
#    hair_loss  stay_up_late  pressure_level  coffee_consumed  \
# 0          0             2               0                0
# 1          0             0               0                0
# 2          1             3               0                1
# 3          0             2               0                0
# 4          0             2               0                0
#
#    brain_working_duration  stress_level  swimming  hair_washing  dandruff
# 0                       1             0         0             1         0
# 1                       3             0         0             0         0
# 2                       0             0         1             1         0
# 3                       1             0         0             0         0
# 4                       1             0         0             1         0

# %%
X_df = df.drop('hair_loss', axis = 1)
X_df.head( )
# Out:
#    stay_up_late  pressure_level  coffee_consumed  brain_working_duration  \
# 0             2               0                0                       1
# 1             0               0                0                       3
# 2             3               0                1                       0
# 3             2               0                0                       1
# 4             2               0                0                       1
#
#    stress_level  swimming  hair_washing  dandruff
# 0             0         0             1         0
# 1             0         0             0         0
# 2             0         1             1         0
# 3             0         0             0         0
# 4             0         0             1         0

# %% [markdown]
# - 라벨링을 마친 데이터를 종속 변수와 독립 변수로 분리
# - 머리 숱(hair_loss)을 Y_data에, 나머지를 X_data에 담는다.

# %%
X_data = X_df.to_numpy( )
X_data.shape
# Out:
# (400, 8)

# %%
Y_data = df['hair_loss'].to_numpy( )
Y_data.shape
# Out:
# (400,)

# %% [markdown]
# - 분리된 데이터를 훈련 데이터와 테스트 데이터로 나눠 준다.
# - 데이터 양이 많지 않으므로 테스트 데이터를 5% 실행
#
# - X_train : 380명의 8개 속성 데이터
# - X_test : 20명의 8개 속성 데이터
# - Y_train : 280명의 탈모 정도
# - Y_test : 20명의 탈모 정도

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size = 0.05, random_state = 42)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((380, 8), (20, 8), (380,), (20,))

# %% [markdown]
# # k-NN 모델 학습하기

# %% [markdown]
# - k-NN 알고리즘인 KNeighborsClassifier 호출하고 모델을 불러옴.
# - **n_neighbors** : k 값

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors = 3)

# %%
#knn 모델 학습
knn_model.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# score() 함수로 학습 데이터의 정확도 확인하니 93.6%가 나옴
# score() 함수로 테스트 데이터로 평가한 결과 80%라는 다소 낮은 정확도가 나옴

# %%
knn_model.score(X_train, Y_train)
# Out:
# 0.9368421052631579

# %%
knn_model.score(X_test, Y_test)
# Out:
# 0.8

# %% [markdown]
# k값에 따라 어떻게 정확도가 바뀌는지 확인해보자

# %% [markdown]
# - k_list 변수에 1~50 저장
# - 훈련 데이터, 테스트 데이터의 정확도를 저장하기 위해 acc_train, acc_test 생성
#
# - 반복문을 이용해 k-NN모델 선언
# - 훈련 데이터로 학습 후 훈련 데이터 정확도와 테스트 데이터 정확도를 각각 저장함

# %%
k_list = range(1,50)
acc_train = [ ]
acc_test = [ ]
for k in k_list:
  classifier = KNeighborsClassifier(n_neighbors = k)
  classifier.fit(X_train, Y_train)
  acc_train.append(classifier.score(X_train, Y_train))
  acc_test.append(classifier.score(X_test, Y_test))
plt.plot(k_list, acc_train, label = 'train')
plt.plot(k_list, acc_test, label = 'test')
plt.xlabel("k")
plt.ylabel("Accuracy")
plt.title("Hair Loss Classifier Accuracy")
plt.legend( )
plt.show( )

# %% [markdown]
# - k 값이 커질수록 정확도가 낮아짐
# - 실제  활용을 위해서는 테스트 데이터의 정확도가 중요
# - 정확도는 최대 85%정도로 나타남

# %% [markdown]
# **k-NN 모델 혼동 행렬**
# - 정확도 80%, 탈모 정도별 정밀도가 전체적으로 낮은 것을 알 수 있음.
#
# - 탈모 데이터를 k-NN으로 학습하였으나 잘 맞지 않다고 볼 수 있음.

# %%
from sklearn.metrics import classification_report, confusion_matrix
knn_prediction = knn_model.predict(X_test)
print('혼동 행렬\n', confusion_matrix(Y_test, knn_prediction))
print('\n평가 지표\n', classification_report(Y_test, knn_prediction, zero_division = 0))
# Out:
# 혼동 행렬
#  [[ 4  1  0  0]
#  [ 2 10  0  0]
#  [ 0  0  2  0]
#  [ 0  0  1  0]]
#
# 평가 지표
#                precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73         5
#            1       0.91      0.83      0.87        12
#            2       0.67      1.00      0.80         2
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.80        20
#    macro avg       0.56      0.66      0.60        20
# weighted avg       0.78      0.80      0.78        20

# %% [markdown]
# ---

# %% [markdown]
# # 다항 분류 딥러닝 모델 학습하기

# %% [markdown]
# - k-NN은 예상보자 높지 않은 정확도가 나왔으므로 다항 분류 딥러닝 모델로 학습해보자.
# - 탈모 정도를 네 가지로 나누어 벡터값을 담는다
# - 원-핫 인코딩을 해 주어 네 가지 벡터값을 담을 수 있는 리스트로 Y_data를 변환
# - 이미지 개수가 많을 때 batch_size가 작으면 학습 시간이 매우 길어진다

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
#원-핫 인코딩
from keras.utils import to_categorical
Y_encoded = to_categorical(Y_data)
Y = np.asarray(Y_encoded)
Y[0]
# Out:
# array([1., 0., 0., 0.], dtype=float32)

# %% [markdown]
# - 테스트 데이터의 비율 5%로 하여 훈련 데이터와 테스트 데이터로 나눠줌.
# - 입력층, 은닉층 2개, 출력층으로 딥러닝 모델 구성

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y, test_size = 0.05, random_state = 42)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((380, 8), (20, 8), (380, 4), (20, 4))

# %%
tf.random.set_seed(3)
model = Sequential( )
model.add(Dense(72,  input_dim = 8, activation = 'relu'))
model.add(Dense(36, activation = 'relu'))
model.add(Dense(12,  activation = 'relu'))
model.add(Dense(4,  activation = 'softmax'))  #출력층 인공신경세포 수 = 탈모의 정도 카테고리 수 4개

# %% [markdown]
# # 탈모 분류 딥러닝 모델 학습 및 평가

# %% [markdown]
# **loss = categorical_crossentropy로 설정 후 컴파일**
# - 오차 : 0.1051,  정확도 : 94.15%  ⇒  k-NN 모델보다 다소 높음

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(X_train, Y_train,epochs = 150, batch_size = 10, validation_split = 0.10)
# Out:
# Epoch 1/150
# 35/35 [==============================] - 1s 9ms/step - loss: 1.3761 - accuracy: 0.4298 - val_loss: 1.2472 - val_accuracy: 0.4474
# Epoch 2/150
# 35/35 [==============================] - 0s 3ms/step - loss: 1.2200 - accuracy: 0.4883 - val_loss: 1.1976 - val_accuracy: 0.5000
# Epoch 3/150
# 35/35 [==============================] - 0s 3ms/step - loss: 1.1231 - accuracy: 0.4883 - val_loss: 1.0336 - val_accuracy: 0.5000
# Epoch 4/150
# 35/35 [==============================] - 0s 4ms/step - loss: 1.0056 - accuracy: 0.5409 - val_loss: 0.9121 - val_accuracy: 0.8684
# Epoch 5/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8783 - accuracy: 0.7632 - val_loss: 0.8518 - val_accuracy: 0.7105
# Epoch 6/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.7796 - accuracy: 0.7485 - val_loss: 0.7205 - val_accuracy: 0.7632
# Epoch 7/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.7573 - val_loss: 0.6392 - val_accuracy: 0.7632
# Epoch 8/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.6082 - accuracy: 0.8041 - val_loss: 0.5266 - val_accuracy: 0.7895
# Epoch 9/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.5715 - accuracy: 0.7953 - val_loss: 0.4877 - val_accuracy: 0.7632
# Epoch 10/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.5333 - accuracy: 0.8158 - val_loss: 0.4851 - val_accuracy: 0.7368
# Epoch 11/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4999 - accuracy: 0.8158 - val_loss: 0.4423 - val_accuracy: 0.8158
# Epoch 12/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4578 - accuracy: 0.8187 - val_loss: 0.4132 - val_accuracy: 0.8158
# Epoch 13/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.8129 - val_loss: 0.4126 - val_accuracy: 0.7895
# Epoch 14/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8392 - val_loss: 0.3850 - val_accuracy: 0.8421
# Epoch 15/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4066 - accuracy: 0.8363 - val_loss: 0.4080 - val_accuracy: 0.8158
# Epoch 16/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3873 - accuracy: 0.8450 - val_loss: 0.3702 - val_accuracy: 0.8421
# Epoch 17/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3645 - accuracy: 0.8509 - val_loss: 0.3685 - val_accuracy: 0.8421
# Epoch 18/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3531 - accuracy: 0.8626 - val_loss: 0.3476 - val_accuracy: 0.8947
# Epoch 19/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3497 - accuracy: 0.8538 - val_loss: 0.3565 - val_accuracy: 0.8158
# Epoch 20/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3368 - accuracy: 0.8830 - val_loss: 0.3886 - val_accuracy: 0.8421
# Epoch 21/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3255 - accuracy: 0.8713 - val_loss: 0.3859 - val_accuracy: 0.8421
# Epoch 22/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3132 - accuracy: 0.8801 - val_loss: 0.3744 - val_accuracy: 0.8421
# Epoch 23/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3337 - accuracy: 0.8743 - val_loss: 0.4106 - val_accuracy: 0.8158
# Epoch 24/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2955 - accuracy: 0.8918 - val_loss: 0.3792 - val_accuracy: 0.9211
# Epoch 25/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3064 - accuracy: 0.8684 - val_loss: 0.3925 - val_accuracy: 0.7895
# Epoch 26/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2893 - accuracy: 0.8947 - val_loss: 0.3698 - val_accuracy: 0.8421
# Epoch 27/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3087 - accuracy: 0.8743 - val_loss: 0.3644 - val_accuracy: 0.8421
# Epoch 28/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2940 - accuracy: 0.8713 - val_loss: 0.4708 - val_accuracy: 0.8421
# Epoch 29/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3095 - accuracy: 0.8713 - val_loss: 0.4070 - val_accuracy: 0.7895
# Epoch 30/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2741 - accuracy: 0.8772 - val_loss: 0.3567 - val_accuracy: 0.8684
# Epoch 31/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.2743 - accuracy: 0.8889 - val_loss: 0.3402 - val_accuracy: 0.8684
# Epoch 32/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2570 - accuracy: 0.8918 - val_loss: 0.4481 - val_accuracy: 0.8158
# Epoch 33/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2769 - accuracy: 0.8743 - val_loss: 0.3690 - val_accuracy: 0.8421
# Epoch 34/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.2703 - accuracy: 0.8830 - val_loss: 0.3905 - val_accuracy: 0.8421
# Epoch 35/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2482 - accuracy: 0.8918 - val_loss: 0.3675 - val_accuracy: 0.8684
# Epoch 36/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.2391 - accuracy: 0.9181 - val_loss: 0.3648 - val_accuracy: 0.9211
# Epoch 37/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2717 - accuracy: 0.8801 - val_loss: 0.3556 - val_accuracy: 0.8158
# Epoch 38/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2557 - accuracy: 0.8977 - val_loss: 0.3345 - val_accuracy: 0.8684
# Epoch 39/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2398 - accuracy: 0.9006 - val_loss: 0.3998 - val_accuracy: 0.8421
# Epoch 40/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2376 - accuracy: 0.8947 - val_loss: 0.3494 - val_accuracy: 0.8421
# Epoch 41/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9211 - val_loss: 0.3586 - val_accuracy: 0.8421
# Epoch 42/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.2266 - accuracy: 0.9035 - val_loss: 0.3675 - val_accuracy: 0.8684
# Epoch 43/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.2332 - accuracy: 0.9035 - val_loss: 0.3499 - val_accuracy: 0.8684
# Epoch 44/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.2096 - accuracy: 0.9123 - val_loss: 0.3554 - val_accuracy: 0.8947
# Epoch 45/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2187 - accuracy: 0.9035 - val_loss: 0.3452 - val_accuracy: 0.9211
# Epoch 46/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2080 - accuracy: 0.8977 - val_loss: 0.3784 - val_accuracy: 0.9211
# Epoch 47/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1992 - accuracy: 0.9298 - val_loss: 0.3948 - val_accuracy: 0.8158
# Epoch 48/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1956 - accuracy: 0.9123 - val_loss: 0.3776 - val_accuracy: 0.8684
# Epoch 49/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1961 - accuracy: 0.9269 - val_loss: 0.3798 - val_accuracy: 0.8421
# Epoch 50/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2111 - accuracy: 0.9094 - val_loss: 0.3934 - val_accuracy: 0.8158
# Epoch 51/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1986 - accuracy: 0.9152 - val_loss: 0.3237 - val_accuracy: 0.9211
# Epoch 52/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2107 - accuracy: 0.9240 - val_loss: 0.4291 - val_accuracy: 0.8421
# Epoch 53/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1870 - accuracy: 0.9181 - val_loss: 0.3453 - val_accuracy: 0.8421
# Epoch 54/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1762 - accuracy: 0.9327 - val_loss: 0.4064 - val_accuracy: 0.8684
# Epoch 55/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1933 - accuracy: 0.9152 - val_loss: 0.3477 - val_accuracy: 0.8947
# Epoch 56/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1687 - accuracy: 0.9269 - val_loss: 0.3746 - val_accuracy: 0.8158
# Epoch 57/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1739 - accuracy: 0.9386 - val_loss: 0.3793 - val_accuracy: 0.8421
# Epoch 58/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1793 - accuracy: 0.9211 - val_loss: 0.3945 - val_accuracy: 0.8158
# Epoch 59/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1724 - accuracy: 0.9327 - val_loss: 0.3760 - val_accuracy: 0.8684
# Epoch 60/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1737 - accuracy: 0.9240 - val_loss: 0.4194 - val_accuracy: 0.8158
# Epoch 61/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1674 - accuracy: 0.9181 - val_loss: 0.4150 - val_accuracy: 0.8947
# Epoch 62/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1671 - accuracy: 0.9327 - val_loss: 0.3897 - val_accuracy: 0.8947
# Epoch 63/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1571 - accuracy: 0.9415 - val_loss: 0.4952 - val_accuracy: 0.8947
# Epoch 64/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.9327 - val_loss: 0.3891 - val_accuracy: 0.7895
# Epoch 65/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9181 - val_loss: 0.4317 - val_accuracy: 0.7895
# Epoch 66/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1523 - accuracy: 0.9357 - val_loss: 0.4282 - val_accuracy: 0.8421
# Epoch 67/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1541 - accuracy: 0.9444 - val_loss: 0.3764 - val_accuracy: 0.8684
# Epoch 68/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1471 - accuracy: 0.9357 - val_loss: 0.3874 - val_accuracy: 0.8421
# Epoch 69/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.9327 - val_loss: 0.3681 - val_accuracy: 0.7895
# Epoch 70/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9386 - val_loss: 0.4196 - val_accuracy: 0.8421
# Epoch 71/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1669 - accuracy: 0.9357 - val_loss: 0.4021 - val_accuracy: 0.7895
# Epoch 72/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1495 - accuracy: 0.9327 - val_loss: 0.3907 - val_accuracy: 0.8421
# Epoch 73/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1437 - accuracy: 0.9386 - val_loss: 0.4151 - val_accuracy: 0.7895
# Epoch 74/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1522 - accuracy: 0.9240 - val_loss: 0.3830 - val_accuracy: 0.8421
# Epoch 75/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1421 - accuracy: 0.9415 - val_loss: 0.3928 - val_accuracy: 0.8684
# Epoch 76/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1377 - accuracy: 0.9415 - val_loss: 0.4387 - val_accuracy: 0.8421
# Epoch 77/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1348 - accuracy: 0.9474 - val_loss: 0.4535 - val_accuracy: 0.8684
# Epoch 78/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.9269 - val_loss: 0.4353 - val_accuracy: 0.8684
# Epoch 79/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1324 - accuracy: 0.9415 - val_loss: 0.3979 - val_accuracy: 0.8947
# Epoch 80/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9415 - val_loss: 0.4340 - val_accuracy: 0.8684
# Epoch 81/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1257 - accuracy: 0.9474 - val_loss: 0.3944 - val_accuracy: 0.8947
# Epoch 82/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.9444 - val_loss: 0.3812 - val_accuracy: 0.8947
# Epoch 83/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.9503 - val_loss: 0.5377 - val_accuracy: 0.8421
# Epoch 84/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1442 - accuracy: 0.9357 - val_loss: 0.3669 - val_accuracy: 0.8684
# Epoch 85/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2024 - accuracy: 0.9269 - val_loss: 0.5274 - val_accuracy: 0.8158
# Epoch 86/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1333 - accuracy: 0.9474 - val_loss: 0.4642 - val_accuracy: 0.8947
# Epoch 87/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1342 - accuracy: 0.9415 - val_loss: 0.4472 - val_accuracy: 0.8947
# Epoch 88/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9444 - val_loss: 0.4826 - val_accuracy: 0.7895
# Epoch 89/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1459 - accuracy: 0.9269 - val_loss: 0.3898 - val_accuracy: 0.8421
# Epoch 90/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.9532 - val_loss: 0.5554 - val_accuracy: 0.8947
# Epoch 91/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1614 - accuracy: 0.9240 - val_loss: 0.4672 - val_accuracy: 0.8947
# Epoch 92/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.9444 - val_loss: 0.4046 - val_accuracy: 0.8684
# Epoch 93/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1196 - accuracy: 0.9474 - val_loss: 0.5019 - val_accuracy: 0.8684
# Epoch 94/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9386 - val_loss: 0.4635 - val_accuracy: 0.8684
# Epoch 95/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9415 - val_loss: 0.5602 - val_accuracy: 0.8421
# Epoch 96/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1178 - accuracy: 0.9415 - val_loss: 0.4442 - val_accuracy: 0.8684
# Epoch 97/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1271 - accuracy: 0.9444 - val_loss: 0.4476 - val_accuracy: 0.8684
# Epoch 98/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1395 - accuracy: 0.9386 - val_loss: 0.5603 - val_accuracy: 0.8684
# Epoch 99/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1159 - accuracy: 0.9444 - val_loss: 0.4568 - val_accuracy: 0.8684
# Epoch 100/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1156 - accuracy: 0.9386 - val_loss: 0.4576 - val_accuracy: 0.8158
# Epoch 101/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1054 - accuracy: 0.9444 - val_loss: 0.4609 - val_accuracy: 0.8947
# Epoch 102/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.9561 - val_loss: 0.3903 - val_accuracy: 0.8684
# Epoch 103/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1224 - accuracy: 0.9474 - val_loss: 0.4551 - val_accuracy: 0.8947
# Epoch 104/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1151 - accuracy: 0.9327 - val_loss: 0.4898 - val_accuracy: 0.8421
# Epoch 105/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1123 - accuracy: 0.9444 - val_loss: 0.3997 - val_accuracy: 0.8947
# Epoch 106/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1342 - accuracy: 0.9327 - val_loss: 0.4649 - val_accuracy: 0.8158
# Epoch 107/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1830 - accuracy: 0.9269 - val_loss: 0.5481 - val_accuracy: 0.8947
# Epoch 108/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1248 - accuracy: 0.9444 - val_loss: 0.4067 - val_accuracy: 0.8684
# Epoch 109/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1183 - accuracy: 0.9357 - val_loss: 0.4780 - val_accuracy: 0.8158
# Epoch 110/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1120 - accuracy: 0.9532 - val_loss: 0.5471 - val_accuracy: 0.8947
# Epoch 111/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1130 - accuracy: 0.9474 - val_loss: 0.5262 - val_accuracy: 0.8947
# Epoch 112/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1074 - accuracy: 0.9532 - val_loss: 0.4997 - val_accuracy: 0.8421
# Epoch 113/150
# 35/35 [==============================] - 0s 6ms/step - loss: 0.1119 - accuracy: 0.9386 - val_loss: 0.4873 - val_accuracy: 0.8421
# Epoch 114/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1189 - accuracy: 0.9298 - val_loss: 0.4939 - val_accuracy: 0.8684
# Epoch 115/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1230 - accuracy: 0.9444 - val_loss: 0.5753 - val_accuracy: 0.8947
# Epoch 116/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1092 - accuracy: 0.9503 - val_loss: 0.4601 - val_accuracy: 0.8158
# Epoch 117/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9503 - val_loss: 0.6021 - val_accuracy: 0.8947
# Epoch 118/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1066 - accuracy: 0.9444 - val_loss: 0.4234 - val_accuracy: 0.8947
# Epoch 119/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 0.9474 - val_loss: 0.5089 - val_accuracy: 0.8684
# Epoch 120/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1021 - accuracy: 0.9386 - val_loss: 0.4832 - val_accuracy: 0.8421
# Epoch 121/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.9561 - val_loss: 0.4670 - val_accuracy: 0.8158
# Epoch 122/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1195 - accuracy: 0.9386 - val_loss: 0.4943 - val_accuracy: 0.8421
# Epoch 123/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1120 - accuracy: 0.9444 - val_loss: 0.4915 - val_accuracy: 0.8684
# Epoch 124/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1119 - accuracy: 0.9357 - val_loss: 0.6577 - val_accuracy: 0.8947
# Epoch 125/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1230 - accuracy: 0.9327 - val_loss: 0.4504 - val_accuracy: 0.8947
# Epoch 126/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1085 - accuracy: 0.9503 - val_loss: 0.5137 - val_accuracy: 0.8684
# Epoch 127/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1141 - accuracy: 0.9298 - val_loss: 0.4927 - val_accuracy: 0.8684
# Epoch 128/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9561 - val_loss: 0.5514 - val_accuracy: 0.8947
# Epoch 129/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1064 - accuracy: 0.9532 - val_loss: 0.5058 - val_accuracy: 0.8947
# Epoch 130/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1067 - accuracy: 0.9444 - val_loss: 0.4945 - val_accuracy: 0.8158
# Epoch 131/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 0.9474 - val_loss: 0.5307 - val_accuracy: 0.8684
# Epoch 132/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.9532 - val_loss: 0.5525 - val_accuracy: 0.8947
# Epoch 133/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1076 - accuracy: 0.9503 - val_loss: 0.6714 - val_accuracy: 0.8947
# Epoch 134/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1084 - accuracy: 0.9415 - val_loss: 0.5480 - val_accuracy: 0.8158
# Epoch 135/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1033 - accuracy: 0.9561 - val_loss: 0.4827 - val_accuracy: 0.8158
# Epoch 136/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1076 - accuracy: 0.9444 - val_loss: 0.4792 - val_accuracy: 0.8947
# Epoch 137/150
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1283 - accuracy: 0.9211 - val_loss: 0.7107 - val_accuracy: 0.8947
# Epoch 138/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1103 - accuracy: 0.9503 - val_loss: 0.6793 - val_accuracy: 0.8421
# Epoch 139/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9474 - val_loss: 0.5004 - val_accuracy: 0.8684
# Epoch 140/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1169 - accuracy: 0.9386 - val_loss: 0.6644 - val_accuracy: 0.8684
# Epoch 141/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1124 - accuracy: 0.9474 - val_loss: 0.6729 - val_accuracy: 0.8947
# Epoch 142/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1056 - accuracy: 0.9357 - val_loss: 0.5882 - val_accuracy: 0.8684
# Epoch 143/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1043 - accuracy: 0.9532 - val_loss: 0.6426 - val_accuracy: 0.8947
# Epoch 144/150
# 35/35 [==============================] - 0s 4ms/step - loss: 0.1174 - accuracy: 0.9357 - val_loss: 0.6452 - val_accuracy: 0.8684
# Epoch 145/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1124 - accuracy: 0.9503 - val_loss: 0.6089 - val_accuracy: 0.8684
# Epoch 146/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1101 - accuracy: 0.9415 - val_loss: 0.6431 - val_accuracy: 0.8947
# Epoch 147/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1207 - accuracy: 0.9444 - val_loss: 0.5570 - val_accuracy: 0.8947
# Epoch 148/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0960 - accuracy: 0.9474 - val_loss: 0.6250 - val_accuracy: 0.8947
# Epoch 149/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 0.9532 - val_loss: 0.4959 - val_accuracy: 0.8947
# Epoch 150/150
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0997 - accuracy: 0.9561 - val_loss: 0.5495 - val_accuracy: 0.8684

# %% [markdown]
# **evaluate() 함수로 테스트 데이터 예측한 결과**
# - 오차 : 0.25,  정확도 : 95%  ⇒  k-NN의 테스트 데이터 정확도보다 훨씬 높음

# %%
model.evaluate(X_test, Y_test)
# Out:
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3136 - accuracy: 0.9500
# [0.3136201798915863, 0.949999988079071]
